# %%
# Initialize client
import os
import json
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage
from textwrap import indent
from dotenv import load_dotenv
# Load environment variables
load_dotenv()

import warnings
warnings.filterwarnings('ignore')

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
def compare_prompts(raw_prompt: str, tuned_prompt: str, title="Prompt Comparison"):
    """
    Compares raw vs Tuned prompt using the same LLM.
    """
    print(title)
    print("+"*50)

    # RAW Prompt and call LLM with it
    raw_message = [
        SystemMessage(content="You are a very helpful assistant."),
        HumanMessage(content=raw_prompt)
    ]

    raw_response = llm(raw_message)
    raw_content = raw_response.content.strip()


    # Tuned Prompt and call LLM with it
    tuned_message = [
        SystemMessage(content="You are a very helpful assistant."),
        HumanMessage(content=tuned_prompt)
    ]

    tuned_response = llm(tuned_message)
    tuned_content = tuned_response.content.strip()

    
    # PRINT OUTPUTS
    print("RAW PROMPT:")
    print("--------------------------------")
    print(raw_prompt)
    print("\nRAW RESPONSE:")
    print(indent(raw_content, "    "))

    print("\n\nTUNED PROMPT:")
    print("--------------------------------")
    print(tuned_prompt)
    print("\nTUNED RESPONSE:")
    print(indent(tuned_content, "    "))

    print("\n==============================")
    print("END OF COMPARISON")

# %%
# EXAMPLE USAGE — FINTECH LOAN DECISION EXPLAINER

raw_prompt_loan = """
Explain why the customer was denied the loan.
"""

tuned_prompt_loan = """
You are a financial assistant that explains loan decisions clearly.

Rules:
• Do NOT invent reasons — only use provided ones.
• Do NOT mention internal scoring systems.
• Be supportive and simple.
• Provide next steps.

Input:
Loan Status: DENIED
Reason Provided: Low credit history, missing income documents.

Format:
1. Summary
2. Main Factors (bullets)
3. Next Steps
"""

compare_prompts(raw_prompt_loan, tuned_prompt_loan, title="Loan Explainer")
# Out:
# Loan Explainer
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# RAW PROMPT:
# --------------------------------
#
# Explain why the customer was denied the loan.
#
#
# RAW RESPONSE:
#     To provide a specific explanation for why a customer was denied a loan, I would need more context about the situation, such as the customer's financial history, credit score, income level, debt-to-income ratio, or any other relevant factors considered by the lender. However, I can outline some common reasons why loan applications are typically denied:
#
#     1. **Low Credit Score**: A credit score below the lender's minimum requirement can lead to a denial. Lenders use credit scores to assess the risk of lending money.
#
#     2. **Insufficient Income**: If the applicant's income is not sufficient to cover the loan payments, the lender may deny the application. Lenders often look for a stable income that meets a certain threshold.
#
#     3. **High Debt-to-Income Ratio**: A high ratio of existing debt to income can indicate that the applicant may struggle to repay additional debt. Lenders typically prefer a debt-to-income ratio below a certain percentage.
#
#     4. **Lack of Credit History**: A limited or nonexistent credit history can make it difficult for lenders to assess the applicant's creditworthiness.
#
#     5. **Employment History**: A lack of stable employment or frequent job changes can raise concerns for lenders about the applicant's ability to repay the loan.
#
#     6. **Negative Financial History**: Previous bankruptcies, foreclosures, or defaults can significantly impact an applicant's chances of loan approval.
#
#     7. **Incomplete Application**: If the loan application is missing required information or documentation, it may be denied.
#
#     8. **Collateral Issues**: For secured loans, if the collateral does not meet the lender's requirements or is insufficient in value, the loan may be denied.
#
#     9. **Loan Purpose**: Some lenders have restrictions on the purpose of the loan, and if the intended use does not align with their policies, the application may be denied.
#
#     If you have specific details about the customer's situation, I can provide a more tailored explanation.
#
#
# TUNED PROMPT:
# --------------------------------
#
# You are a financial assistant that explains loan decisions clearly.
#
# Rules:
# • Do NOT invent reasons — only use provided ones.
# • Do NOT mention internal scoring systems.
# • Be supportive and simple.
# • Provide next steps.
#
# Input:
# Loan Status: DENIED
# Reason Provided: Low credit history, missing income documents.
#
# Format:
# 1. Summary
# 2. Main Factors (bullets)
# 3. Next Steps
#
#
# TUNED RESPONSE:
#     1. **Summary**
#     Your loan application has been denied. This decision is based on a couple of important factors related to your financial profile.
#
#     2. **Main Factors**
#     - Low credit history
#     - Missing income documents
#
#     3. **Next Steps**
#     - Consider improving your credit history by making timely payments on existing debts and avoiding new debt.
#     - Gather and submit the necessary income documents to support your application.
#     - Once you have addressed these factors, you can reapply for the loan. If you have any questions or need assistance, feel free to ask!
#
# ==============================
# END OF COMPARISON

# %%
raw_prompt_vector_db = "Explain what a vector database is."

tuned_prompt_vector_db = """
You are explaining to a Product Manager with no machine learning background.

Context:
The listener understands products and user experience but not AI terminology.

Task:
Explain what a Vector Database is.

Instructions:
1. Use one real-life analogy
2. Use one popular app example (Google, Netflix, or Amazon)
3. Explain why it is useful, not how it is built

Constraints:
- No math
- No technical or ML jargon
- Simple, conversational language
- Maximum 120 words

Output format:
- Analogy
- App example
- Why it matters
"""

compare_prompts(raw_prompt_vector_db, tuned_prompt_vector_db, title="Vector DB explanation")
# Out:
# Vector DB explanation
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# RAW PROMPT:
# --------------------------------
# Explain what a vector database is.
#
# RAW RESPONSE:
#     A vector database is a specialized type of database designed to store, manage, and retrieve high-dimensional vector data efficiently. This type of database is particularly useful in applications involving machine learning, natural language processing, computer vision, and other fields where data can be represented as vectors in a multi-dimensional space.
#
#     ### Key Features of Vector Databases:
#
#     1. **High-Dimensional Data Storage**: Vector databases can handle data represented as vectors, which are arrays of numbers that can represent various types of information, such as text embeddings, image features, or any other numerical representation of data.
#
#     2. **Similarity Search**: One of the primary functions of a vector database is to perform similarity searches. This involves finding vectors that are close to a given vector in the high-dimensional space, often using distance metrics like Euclidean distance, cosine similarity, or others. This is crucial for applications like recommendation systems, image retrieval, and semantic search.
#
#     3. **Scalability**: Vector databases are designed to scale efficiently with large datasets, allowing for quick retrieval and processing of vectors even as the volume of data grows.
#
#     4. **Indexing Techniques**: To facilitate fast similarity searches, vector databases often employ advanced indexing techniques such as Approximate Nearest Neighbor (ANN) algorithms, which help in quickly locating the nearest vectors without having to compare every vector in the dataset.
#
#     5. **Integration with Machine Learning**: Vector databases are often used in conjunction with machine learning models that generate vector representations of data (e.g., embeddings from neural networks). This allows for seamless storage and retrieval of these representations for further analysis or application.
#
#     ### Use Cases:
#
#     - **Recommendation Systems**: Finding similar items based on user preferences or item characteristics.
#     - **Image and Video Retrieval**: Searching for images or videos that are visually similar to a given input.
#     - **Natural Language Processing**: Searching for documents or sentences that are semantically similar based on their vector representations.
#     - **Anomaly Detection**: Identifying outliers in high-dimensional data by analyzing vector distances.
#
#     ### Examples of Vector Databases:
#
#     Some popular vector databases and libraries include:
#
#     - **Pinecone**: A managed vector database service that provides scalable and efficient similarity search.
#     - **Weaviate**: An open-source vector search engine that integrates with machine learning models.
#     - **Milvus**: An open-source vector database designed for high-performance similarity search and analytics.
#     - **Faiss**: A library developed by Facebook AI Research for efficient similarity search and clustering of dense vectors.
#
#     In summary, vector databases are essential tools for managing and querying high-dimensional data, enabling a wide range of applications in AI and data science.
#
#
# TUNED PROMPT:
# --------------------------------
#
# You are explaining to a Product Manager with no machine learning background.
#
# Context:
# The listener understands products and user experience but not AI terminology.
#
# Task:
# Explain what a Vector Database is.
#
# Instructions:
# 1. Use one real-life analogy
# 2. Use one popular app example (Google, Netflix, or Amazon)
# 3. Explain why it is useful, not how it is built
#
# Constraints:
# - No math
# - No technical or ML jargon
# - Simple, conversational language
# - Maximum 120 words
#
# Output format:
# - Analogy
# - App example
# - Why it matters
#
#
# TUNED RESPONSE:
#     Imagine a library where each book is organized not just by title or author, but by themes and ideas. A vector database works similarly, storing information in a way that helps find connections between different pieces of data.
#
#     Think of Netflix: when you finish a movie, it suggests others you might like based on your viewing habits. This is powered by a vector database that understands the relationships between different films.
#
#     This matters because it helps users discover content or products that truly match their interests, making their experience more enjoyable and personalized. It’s all about connecting the dots in a way that feels intuitive and relevant.
#
# ==============================
# END OF COMPARISON

# %%
[ROLE] -> Audience information

[CONTEXT] -> Background Info

[TASK] -> What is to be done

[CONSTRAINTS] -> [Word Limits, tone, length, tools, things to avoid]

[OUTPUT FORMAT] -> Very clear format as to what you expect the model to respond with

# %% [markdown]
# ## Chain of Thought

# %%
# Define reasoning templates for different problem types
REASONING_TEMPLATES = {
    "math_word_problem": """
Let's think through this step by step:
1. First, identify what the problem is asking for
2. Extract the relevant numbers and variables
3. Determine the mathematical operations needed
4. Set up the equation or calculation
5. Solve step by step
6. Verify the answer makes sense
""",

    "logical_deduction": """
Let's reason through this logically:
1. List all the given facts and constraints
2. Identify relationships between elements
3. Look for contradictions or implications
4. Make inferences from the available information
5. Build conclusions step by step
6. Check for consistency
""",

    "code_debugging": """
Let's debug this systematically:
1. Understand what the code should do vs what it actually does
2. Identify the specific error or unexpected behavior
3. Trace through the code execution step by step
4. Check variable values and data flow
5. Isolate the problematic section
6. Propose and test fixes
"""
}

# %%
# Example problems - you can replace these dynamically
problems = {
    "math_problem": "If a store has 15 apples and sells 8, then receives a shipment of 12 more apples, how many apples do they have now?",
    
    "logic_puzzle": "There are three people: Alice, Bob, and Charlie. Alice is taller than Bob. Charlie is shorter than Bob. Who is the tallest?",
    
    "debugging_issue": "This Python function should return the sum of even numbers in a list, but it's returning incorrect results:\n\n```python\ndef sum_even_numbers(numbers):\n    total = 0\n    for num in numbers:\n        if num % 2 == 0:\n            total += num\n    return total\n\n# Test case: sum_even_numbers([1, 2, 3, 4, 5, 6]) returns 9 instead of 12\n```"
}

# %%
problem = problems["math_problem"]
problem_type = "math_word_problem"

# %%
prompt = f"""
You are an AI reasoning assistant. Your task is to solve prolems using step-by-step reasoning.

PROBLEM:
{problem}

REASONING_APPROACH:
{REASONING_TEMPLATES[problem_type]}

Please work through this problem sytematically and show your reasoning at each step before providing the final answer.

Format the response like this:
Step 1: <....>
step 2: <....>
.
.

Final Answer: <>

"""

# %%
print(prompt)
# Out:
# You are an AI reasoning assistant. Your task is to solve prolems using step-by-step reasoning.
#
# PROBLEM:
# If a store has 15 apples and sells 8, then receives a shipment of 12 more apples, how many apples do they have now?
#
# REASONING_APPROACH:
#
# Let's think through this step by step:
# 1. First, identify what the problem is asking for
# 2. Extract the relevant numbers and variables
# 3. Determine the mathematical operations needed
# 4. Set up the equation or calculation
# 5. Solve step by step
# 6. Verify the answer makes sense
#
#
# Please work through this problem sytematically and show your reasoning at each step before providing the final answer.
#
# Format the response like this:
# Step 1: <....>
# step 2: <....>
# .
# .
#
# Final Answer: <>

# %%
messages = [
    SystemMessage(content="You are a helpful, clear and careful assistant. Provide a concise final answer and a brief, high level stepwise summary."),
    HumanMessage(content=prompt)
]

# %%
response = llm(messages)
response_content = response.content

# %%
print(response_content)
# Out:
# Step 1: Identify what the problem is asking for.
# The problem is asking for the total number of apples the store has after selling some and receiving a shipment.
#
# Step 2: Extract the relevant numbers and variables.
# - Initial number of apples: 15
# - Apples sold: 8
# - Apples received in shipment: 12
#
# Step 3: Determine the mathematical operations needed.
# We need to subtract the number of apples sold from the initial number of apples, and then add the number of apples received in the shipment.
#
# Step 4: Set up the equation or calculation.
# Total apples after selling and receiving shipment = (Initial apples - Apples sold) + Apples received
# = (15 - 8) + 12
#
# Step 5: Solve step by step.
# - First, calculate the number of apples left after selling:
#   15 - 8 = 7
# - Next, add the apples received in the shipment:
#   7 + 12 = 19
#
# Step 6: Verify the answer makes sense.
# Initially, there were 15 apples. After selling 8, there were 7 left. Receiving 12 more apples gives a total of 19 apples, which is reasonable.
#
# Final Answer: 19
